# %% [markdown]
# <a href="https://colab.research.google.com/github/Afif-Shadman/Colab/blob/main/sdxl_promptlist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #duffusion starting

# %%
# !pip install diffusers["torch"] transformers
# !pip install accelerate
# !pip install git+https://github.com/huggingface/diffusers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 16.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...

# %%
from diffusers import AutoPipelineForText2Image, DPMSolverMultistepScheduler
import torch

pipe = AutoPipelineForText2Image.from_pretrained('lykon/dreamshaper-xl-v2-turbo', torch_dtype=torch.float16, variant="fp16")
pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
pipe = pipe.to("cuda")
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/diffusers/models/transformers/transformer_2d.py:34: FutureWarning: `Transformer2DModelOutput` is deprecated and will be removed in version 1.0.0. Importing `Transformer2DModelOutput` from `diffusers.models.transformer_2d` is deprecated and this will be removed in a future version. Please use `from diffusers.models.modeling_outputs import Transformer2DModelOutput`, instead.
#   deprecate("Transformer2DModelOutput", "1.0.0", deprecation_message)
# ...

# %% [markdown]
# #Mounting drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #List of prompts and iterator

# %%
i = 0
promptlist =[
"A close-up shot of a puddle on a city sidewalk captures a mesmerizing display of fractal patterns. The rippling water reflects the fragmented image of the sky above, creating a kaleidoscope of blues and grays. The diffused sunlight adds a touch of softness to the scene, while the macro lens reveals the intricate details of the water's surface. The overall impression is one of coldness and isolation, a world reduced to pure form and texture.",
"A black and white close-up of a weathered fire escape transforms the ordinary into the extraordinary. The rusted metal surface is captured in exquisite detail, its texture a web of lines and cracks. The red tones of the rust add a pop of color against the stark black and white background. The flat lighting emphasizes the two-dimensional quality of the image, further blurring the lines between representation and abstraction",
"A long exposure photograph taken with intentional camera movement captures the frenetic energy of a city at night. The city skyline is transformed into a blur of light and color, the individual buildings merging into a single streak of movement. The trails of light from cars and headlights add a sense of dynamism to the scene. The overall impression is one of chaos and motion, a world in constant flux.",
"A close-up shot of a colorful graffiti mural isolates the abstract elements of street art. The spray paint creates a layered composition of shapes and colors, with hints of the underlying wall peeking through. The focus is on the interplay of form and texture, rather than on the representational content of the mural. The bright sunlight casts sharp shadows, adding depth and dimension to the image.",
"A macro shot of peeling paint on a wall reveals a hidden world of texture and pattern. The peeling layers create a sense of depth and decay, while the underlying colors peek through like fragments of a forgotten past. The raking sunlight casts long shadows that accentuate the three-dimensionality of the surface. The image is both beautiful and unsettling, a reminder of the impermanence of all things.",
"A long exposure photograph captures the creativity of light painting. The artist uses a flashlight or LED wand to draw abstract shapes in the darkness. The resulting image is a mesmerizing display of light trails, with lines and curves dancing across the black canvas. The controlled movement and color choices create a sense of intentionality, despite the abstract nature of the final product.",
"A high-speed flash freezes the motion of a splashing water droplet. The resulting image captures the explosion of the droplet in exquisite detail, revealing intricate shapes and patterns. The water droplets become abstract sculptures, their original form barely recognizable. The high-speed flash allows for a glimpse into a world invisible to the naked eye, highlighting the dynamic beauty of everyday phenomena.",
"A black and white photograph uses the solarization technique to create a surreal and dreamlike image. The original light and dark areas are reversed, resulting in a disorienting effect. The sky appears dark, while objects on the ground may be rendered white. This technique adds a layer of mystery and intrigue to the scene, blurring the lines between reality and imagination.",
"A multiple exposure photograph combines several images of a cityscape into a single abstract composition. The overlapping layers create a sense of texture and depth, with buildings and streets merging into a kaleidoscope of shapes and colors. This technique allows the photographer to capture the essence of a place in a non-representational way, focusing on the emotions and sensations evoked by the urban environment.",
"A photograph taken with a Lensbaby attachment creates a unique and dreamlike image of a flower. The special lens allows for a narrow band of sharp focus, while the rest of the image is blurred. This selective focus technique transforms the flower into an abstract composition of color and texture. The bokeh effect, created by the blurred areas, adds a touch of softness and mystery to the scene.",
"This variation steps away from the camera altogether. A chemigram is created by directly manipulating light-sensitive paper or film with chemicals in a darkroom. The resulting image is a product of chance and experimentation, with unpredictable patterns and textures emerging from the chemical reactions. This technique allows for a truly abstract and unique expression, where the photographer relinquishes some control to the creative forces of the chemicals.",
"A photogram captures the silhouettes and textures of objects placed directly onto light-sensitive paper in a darkroom. Leaves, flowers, or other organic materials can be used to create unique abstract compositions. The interplay of light and shadow reveals the intricate details of the object, transformed into a negative space image. This approach celebrates the beauty of nature in an abstract form, highlighting the negative space and textures often overlooked in traditional photography.",
"This variation delves into the digital realm. Data moshing involves manipulating the digital data of an image to create glitches, distortions, and unexpected visual effects. The original image can be anything, from a landscape to a portrait. The manipulation process transforms the image into a mesmerizing display of abstract shapes and colors, reflecting the hidden language of digital information. This technique explores the intersection of photography and digital art, questioning the very definition of a photographic image.",
"A macro lens captures the mesmerizing world of light refraction through a crystal prism. The lens focuses on the prism's edge, where the incoming light splits into a rainbow spectrum of colors. The resulting image is a kaleidoscope of vibrant hues, distorted and bent as they pass through the crystal. This exploration of light and its interaction with a simple object allows the photographer to create an abstract world of pure color and form.",
"A black and white macro shot captures the swirling patterns of coffee grounds settling in water. The intricate dance of the grounds creates a mesmerizing display of textures and shapes. The black and white film emphasizes the contrast between the dark coffee grounds and the white water, highlighting the abstract beauty of this everyday phenomenon. This variation finds artistry in the mundane, transforming a simple act of brewing coffee into a meditation on form and movement.",
"A macro lens explores the intricate textures and patterns of ripped and crumpled paper. The close-up view reveals the torn edges, folds, and layers that create a sculptural quality. The play of light and shadow adds depth and dimension to the image. This variation takes a common object, paper, and transforms it into a meditation on decay and the passage of time. The focus on texture and form elevates the ordinary to the extraordinary, creating an abstract composition that invites contemplation.",
"A long exposure photograph on a busy street captures the essence of movement through light trails. The car headlights leave behind streaks of color that dance across the image. The scene becomes a blur of motion and light, a visual representation of the city's energy at night. The wide-angle lens allows for a wide view of the street, emphasizing the dynamic flow of traffic. This variation translates the constant movement of the urban environment into a captivating abstract composition.",
"This variation utilizes camera movement to create an abstract image. During a long exposure, the photographer zooms the lens in or out, creating a blur effect that distorts the subject. The result is an image that is devoid of recognizable shapes, instead focusing on the sensation of movement and the interplay of colors. This technique allows the photographer to explore the relationship between time, space, and perception, translating a simple action into a visually compelling abstraction.",
"A high-speed flash allows for capturing the dynamic moment of a water droplet impacting a surface. The resulting image freezes the splash in mid-air, revealing the intricate patterns and shapes formed by the water droplets. The force of the impact creates a sense of movement and explosion, even though the image is a still photograph. This variation uses high-speed photography to explore the hidden beauty of everyday phenomena, transforming a simple splash into a captivating abstract artwork.",
"A macro lens captures the ephemeral beauty of soap bubbles. The spherical shapes reflect the surrounding light, creating a mesmerizing display of color and iridescence. The thin film of the bubble is both delicate and vibrant, highlighting its fleeting nature. This playful variation finds beauty in the impermanent, using soap bubbles as a metaphor for the fragility and impermanence of life itself.",
"This variation takes advantage of a camera's double exposure function to create unexpected and playful abstract images. Two separate scenes are layered on top of each other in-camera, resulting in a unique blend of shapes and forms. The element of chance adds to the creative process, as the photographer relinquishes some control over the final image. The resulting abstraction can be interpreted in various ways, sparking imagination and curiosity.",
"A kaleidoscope lens attachment transforms an ordinary scene into a mesmerizing display of fractal patterns. The lens replicates the subject multiple times, creating a sense of symmetry and repetition. The vibrant colors and repeating shapes evoke a sense of playfulness and wonder. This variation uses a simple tool to create a captivating abstract world, inviting the viewer to lose themselves in the infinite reflections and patterns.",
"This variation uses fire as a light source to create dynamic abstract art. A long exposure photograph captures the movement of fire spinning, translating the dance of flames into streaks of light and smoke. The resulting image is a mesmerizing interplay of light and darkness, with the fire leaving behind a trail of glowing embers. This variation taps into the primal energy of fire, transforming a performance into a captivating abstract artwork.",
"This variation explores the scientific phenomenon of light diffraction to create mesmerizing abstract art. A diffraction grating, a special material with microscopic slits, splits light into its constituent colors. A macro lens captures the resulting pattern of rainbow bands, showcasing the hidden nature of light. This variation delves into the intersection of science and art, using light as a tool to create a visually stunning abstraction.",
"This variation ventures beyond the earth's atmosphere to capture the abstract beauty of the sun. A specialized solar filter allows the photographer to safely photograph the sun's surface, revealing a world of texture and granulation. The fiery prominences and sunspots create a sense of movement and dynamism, making the sun appear more like an abstract painting than a celestial object. This variation explores the power and mystery of the sun, transforming a familiar sight into a captivating abstract artwork.",
"A macro lens captures the intricate details of crumpled plastic wrap. The once smooth and transparent material is transformed into a landscape of peaks and valleys, with light and shadow highlighting its textures. The play of light creates a sense of depth and dimension, while the ephemeral nature of the plastic wrap adds a touch of melancholy to the image. This variation finds beauty in the discarded and overlooked, transforming a mundane object into a meditation on light and form.",
"A macro lens explores the layers of peeling paint on a weathered fence. The image reveals the history of the fence, with each layer of paint a testament to the passage of time. The cracks and textures create a sense of decay and erosion, adding a sense of narrative to the abstract composition. This variation uses a simple object, a fence, to explore themes of time, history, and the impermanence of all things.",
"A macro lens captures the intricate patterns and textures of crystallized salt. The salt crystals form a mesmerizing landscape of geometric shapes, resembling miniature mountains and valleys. The dark background isolates the crystals, allowing the viewer to appreciate the beauty of their form and the natural process of crystallization. This variation finds artistry in the scientific, showcasing the inherent beauty of salt in its crystallized form.",
"A macro lens explores the vulnerability and beauty of threadbare fabric. The close-up view reveals the worn threads, frayed edges, and small holes that tell a story of use and time. The texture of the fabric becomes the main focus, inviting the viewer to imagine the history of the object and the hands that once held it. This variation uses a simple piece of fabric to evoke emotions of nostalgia, vulnerability, and the passage of time.",
"A macro lens captures the vibrant colors and textures of scattered spices. The image becomes an explosion of color and form, with each spice adding a unique touch to the composition. The play of light and shadow creates a sense of depth and dimension, while the arrangement of the spices suggests a sense of movement and dynamism. This variation celebrates the beauty of everyday spices, transforming them into an abstract artwork that awakens the senses.",
"A macro lens explores the contrasting textures and colors of weathered bolts. The once smooth metal is now covered in rust, creating a rough and uneven surface. The scratches and marks tell a story of wear and tear, hinting at the industrial world where these bolts may have originated. This variation finds beauty in the industrial and utilitarian, transforming a simple bolt into a study of texture, decay, and the passage of time.",
"A macro lens captures the mesmerizing world of fractured glass. The shattered pieces refract light, creating a kaleidoscope of colors and distorted reflections. The sharp edges and jagged lines contrast with the soft light, creating a sense of tension and fragility. This variation explores the inherent beauty and fragility of glass, transforming its destruction into a captivating abstract composition.",
"A slow shutter speed allows for capturing the ethereal movement of smoke rising from incense. The resulting image is a blur of swirling shapes and textures, devoid of recognizable form. The black and white film emphasizes the contrast between the light and dark areas, creating a sense of mystery and intrigue. This variation captures the fleeting nature of smoke, using it as a metaphor for the impermanence of all things.",
"A macro lens explores the captivating world of a holographic sticker. The close-up view reveals the intricate details of the holographic pattern, with its rainbow colors shifting depending on the angle of light. The play of light and shadow creates a sense of depth and dimension, while the holographic effect challenges our perception of reality. This variation uses a playful object to explore themes of light, deception, and the ever-changing nature of our visual world.",
"This variation embraces the beauty of imperfections. A macro lens captures the intricate patterns left behind by evaporating coffee on a saucer. The concentric circles and textured surface create an abstract composition that is both organic and visually appealing. The black and white film option emphasizes the contrast between the coffee stains and the clean background, while the color option allows the natural hues of the coffee to shine through. This variation finds artistry in the everyday act of drinking coffee, celebrating the impermanent beauty created by chance and natural processes.",
"This variation explores the dynamic interplay of color and movement. A drop of paint is gently placed in water, and the resulting swirl is captured with a macro lens. The image becomes a mesmerizing display of color diffusion, with the paint blending and separating in unpredictable ways. This variation taps into the idea of controlled chaos, allowing the photographer to influence the initial movement of the paint but ultimately surrendering the result to the natural flow of the water.",
"This variation embraces the unexpected beauty of imperfections. By intentionally allowing light leaks into a film camera, the photographer creates abstract patterns and streaks on the final image. The light leaks introduce an element of surprise and serendipity to the process, as the photographer never knows exactly how the final image will appear. This variation celebrates the analog nature of film photography and the beauty of imperfections that can arise from happy accidents.",
"This variation utilizes forced perspective to create a playful and surreal abstract image. Everyday objects are arranged in a way that disrupts their sense of scale and creates a sense of wonder. A thimble might appear as tall as a building, and a spoon could become a bridge. The manipulated perspective transforms the familiar into the fantastical, inviting the viewer to question their perception of reality.",
"This variation ventures into the realm of science and sound to create captivating abstract art. Cymatics is the study of visible sound patterns, and this technique involves placing a plate or membrane covered with sand or powder on a speaker and playing sound frequencies. The camera captures the resulting patterns formed by the vibrations, creating an abstract visualization of sound. This variation explores the hidden connections between sound and form, transforming the invisible into the visible.",
"This variation utilizes the infinite reflections of mirrors to create a fragmented and abstract composition. Everyday objects are placed within a multi-mirror setup, and the camera captures the resulting distorted and multiplied images. The fragmented reflections create a sense of disorientation and challenge the viewer's perception of reality. This variation explores themes of deconstruction and multiplicity, using mirrors to break down the form of everyday objects and create a new visual experience.",
"This playful variation transforms everyday food into abstract sculptures. Fruits, vegetables, or even cooked dishes are manipulated and molded into unexpected shapes. The camera captures the close-up details of the sculpted food, highlighting its textures and forms. This variation injects humor and creativity into the process, showcasing the potential for beauty and artistry in unexpected places.",
"This variation delves into the realm of science to create mesmerizing abstract art. Safe and controlled chemical reactions are used to create vibrant colors and swirling patterns. The camera, with a slow shutter speed, captures the movement and evolution of the reaction, resulting in an ever-changing abstract composition. This variation explores the transformative power of chemistry, showcasing the inherent beauty of scientific processes.",
"This variation takes a hands-on approach to create unique and surreal abstract imagery. Film negatives with double exposures are further manipulated by hand-scratching, cutting, and reassembling them before printing. This process allows the photographer to create unexpected and dreamlike compositions, where elements from different exposures merge and transform into a new visual reality. This variation celebrates the handmade aesthetic and the transformative power of analog photograph",
"This variation utilizes motion blur to transform everyday objects into streaks of light and color. Attach string or thread to an object and swing it in front of the camera with a slow shutter speed. The resulting image captures the movement as a blur, creating a sense of dynamism and transformation. The single light source adds a pop of color and emphasizes the path of the object. This variation explores the concept of movement and the relationship between time and space in a captivating abstract composition.",
"This variation takes light painting a step further by utilizing everyday tools as light sources. Attach a small flashlight or LED light to a common household object, like a whisk or a screwdriver. In a dark room, move the tool in various patterns while the camera captures the light trails with a slow shutter speed. The resulting image becomes a unique blend of form and light, showcasing the creative potential of everyday objects. This variation explores the transformative power of light and the element of surprise as the final image is revealed.",
"This variation finds beauty in the act of destruction. Everyday objects are carefully broken or shattered, and then arranged in a way that allows for interesting reflections of light and shadow. The camera, with a macro lens, captures the intricate details of the broken pieces and the way they interact with light. This variation explores the concept of deconstruction and impermanence, transforming a whole object into a fragmented and abstract composition."
]

# %%
prompt = promptlist[i]
print(prompt,i)
i = i+1
print(prompt,i)
# Out:
# A close-up shot of a puddle on a city sidewalk captures a mesmerizing display of fractal patterns. The rippling water reflects the fragmented image of the sky above, creating a kaleidoscope of blues and grays. The diffused sunlight adds a touch of softness to the scene, while the macro lens reveals the intricate details of the water's surface. The overall impression is one of coldness and isolation, a world reduced to pure form and texture. 0
# A close-up shot of a puddle on a city sidewalk captures a mesmerizing display of fractal patterns. The rippling water reflects the fragmented image of the sky above, creating a kaleidoscope of blues and grays. The diffused sunlight adds a touch of softness to the scene, while the macro lens reveals the intricate details of the water's surface. The overall impression is one of coldness and isolation, a world reduced to pure form and texture. 1

# %% [markdown]
# #image generator                                enter number of images to be generated

# %%
import random
from diffusers.utils import make_image_grid, load_image

# %%
num_images = 4 #@param int
for a in range(num_images):
  name = "/content/drive/MyDrive/bulk/abstract art/"+str(a)+".png"
  generator = torch.manual_seed(random.randint(0,100000))
  image = pipe(prompt, num_inference_steps=10, guidance_scale=2).images[0]
  #image.save(name)
# Out:
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['one of coldness and isolation, a world reduced to pure form and texture.']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['one of coldness and isolation, a world reduced to pure form and texture.']
#   0%|          | 0/10 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['one of coldness and isolation, a world reduced to pure form and texture.']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['one of coldness and isolation, a world reduced to pure form and texture.']
#   0%|          | 0/10 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['one of coldness and isolation, a world reduced to pure form and texture.']
# ...

# %%
import torch
from diffusers import AutoPipelineForImage2Image
from diffusers.utils import make_image_grid, load_image

pipeline = AutoPipelineForImage2Image.from_pretrained(
    "runwayml/stable-diffusion-v1-5", torch_dtype=torch.float16, variant="fp16", use_safetensors=True
)
pipeline.enable_model_cpu_offload()
# remove following line if xFormers is not installed or you have PyTorch 2.0 or higher installed
pipeline.enable_xformers_memory_efficient_attention()

# prepare image
url = "https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/diffusers/img2img-init.png"
init_image = load_image(url)

prompt = "Astronaut in a jungle, cold color palette, muted colors, detailed, 8k"

# pass prompt and image to pipeline
image = pipeline(prompt, image=init_image).images[0]
make_image_grid([init_image, image], rows=1, cols=2)
make_image_grid([image[0], image[1],image[2],image[3], rows=1, cols=4)

# %%
name = prompt + str(a)
print("/content/drive/MyDrive/bulk"+name)
# Out:
# /content/drive/MyDrive/bulkA close-up shot of a puddle on a city sidewalk captures a mesmerizing display of fractal patterns. The rippling water reflects the fragmented image of the sky above, creating a kaleidoscope of blues and grays. The diffused sunlight adds a touch of softness to the scene, while the macro lens reveals the intricate details of the water's surface. The overall impression is one of coldness and isolation, a world reduced to pure form and texture.0
